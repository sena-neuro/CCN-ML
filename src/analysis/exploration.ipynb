# %%
import ccn_io
import ccn_preprocess
import ccn_algorithms
import ccn_ml
import ccn_visualization
import numpy as np

# %%
android_data = np.asarray(ccn_io.read_file("/home/user/Desktop/data_eeg/subj01/subj01_android_still.mat")['subj01_android_still'])
# Out:
#     Something went wrong!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-4c4b58e06be0> in <module>
# ----> 1 android_data = np.asarray(ccn_io.read_file("/home/user/Desktop/data_eeg/subj01/subj01_android_still.mat")['subj01_android_still'])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
android_data.shape
# Out:
# (62, 400, 83)

# %%
human_data = np.asarray(ccn_io.read_file("/home/user/Desktop/data_eeg/subj01/subj01_human_still.mat")['subj01_human_still'])

# %%
robot_data = np.asarray(ccn_io.read_file("/home/user/Desktop/data_eeg/subj01/subj01_robot_still.mat")['subj01_robot_still'])

# %%
#android_data_p = np.asarray(ccn_io.read_file("data/android_motion_epochs.mat")["android_motion_epochs"])
#human_data_p = np.asarray(ccn_io.read_file("data/human_motion_epochs.mat")["human_motion_epochs"])
#robot_data_p = np.asarray(ccn_io.read_file("data/robot_motion_epochs.mat")["robot_motion_epochs"])

# %%
and_average_over_trial = np.average(android_data,2)
hum_average_over_trial = np.average(human_data,2)
rob_average_over_trial = np.average(robot_data,2)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot( human_data[1,:,:])

# %%
for ch in range(62):
    plt.plot(rob_average_over_trial[ch])
plt.show()

# %%
for ch in range(62):
    plt.plot(and_average_over_trial[ch])
plt.show()

# %%
for ch in range(62):
    plt.plot(hum_average_over_trial[ch])
plt.show()

# %%
and_average = np.average(android_data,(0,2))
hum_average = np.average(human_data,(0,2))
rob_average= np.average(robot_data,(0,2))

# %%
and_average_p = np.average(android_data_p,(0,2))
hum_average_p = np.average(human_data_p,(0,2))
rob_average_p= np.average(robot_data_p,(0,2))
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-25-8eaf72874a58> in <module>
# ----> 1 and_average_p = np.average(android_data_p,(0,2))
#       2 hum_average_p = np.average(human_data_p,(0,2))
#       3 rob_average_p= np.average(robot_data_p,(0,2))
#
# NameError: name 'android_data_p' is not defined

# %%
plt.plot(and_average_p,color='r')
plt.plot(hum_average_p,color='g')
plt.plot(rob_average_p,color='b')
plt.show()

# %%
plt.plot(and_average,color='r')
plt.plot(hum_average,color='g')
plt.plot(rob_average,color='b')
plt.show()

# %%
plt.plot(hum_average)

# %%
plt.plot(rob_average)

# %%
and_average_over_ch = np.average(android_data,0)
hum_average_over_ch = np.average(human_data,0)
rob_average_over_ch = np.average(robot_data,0)

# %%
for tr in range(90):
    plt.plot(rob_average_over_ch[tr])
plt.show()

# %%
for tr in range(90):
    plt.plot(and_average_over_ch[tr])
plt.show()

# %%
import random
int(random.random()*100)
# Out:
# 69
