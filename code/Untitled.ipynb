# %%
import ccn_io
import ccn_preprocess
import ccn_algorithms
import ccn_ml
import ccn_visualization
import numpy as np

# %%
android_data = np.asarray(ccn_io.read_file("data2/video_android.mat")["video_android"])
human_data = np.asarray(ccn_io.read_file("data2/video_human.mat")["video_human"])
robot_data = np.asarray(ccn_io.read_file("data2/video_robot.mat")["video_robot"])

# %%
android_data.shape
# Out:
# (62, 600, 94)

# %%
and_average_over_trial = np.average(android_data,2)
hum_average_over_trial = np.average(human_data,2)
rob_average_over_trial = np.average(robot_data,2)

# %%
import matplotlib.pyplot as plt

# %%
for ch in range(62):
    plt.plot(rob_average_over_trial[ch])
plt.show()

# %%
for ch in range(62):
    plt.plot(and_average_over_trial[ch])
plt.show()

# %%
for ch in range(62):
    plt.plot(hum_average_over_trial[ch])
plt.show()

# %%
and_average = np.average(android_data,(1,2))
hum_average = np.average(human_data,(1,2))
rob_average= np.average(robot_data,(1,2))

# %%
plt.plot(and_average)

# %%
plt.plot(hum_average)

# %%
plt.plot(rob_average)

# %%
and_average_over_ch = np.average(android_data,0)
hum_average_over_ch = np.average(human_data,0)
rob_average_over_ch = np.average(robot_data,0)

# %%
for tr in range(90):
    plt.plot(rob_average_over_ch[tr])
plt.show()

# %%
for tr in range(90):
    plt.plot(and_average_over_ch[tr])
plt.show()
